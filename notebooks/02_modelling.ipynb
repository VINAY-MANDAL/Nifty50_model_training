# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data_set/row/Nifty_50_India_2000_2026.csv')

cols_to_convert = ['Price', 'Close', 'High', 'Low', 'Open', 'Volume']

for col in cols_to_convert:
    if col in df.columns:

        df[col] = df[col].astype(str).str.replace(',', '')

        df[col] = pd.to_numeric(df[col], errors='coerce')

df.dropna(inplace=True)

print("---New Data Info---")
print(df.info())

print("\n--- Data Head ---")
print(df.head())
# Out:
# ---New Data Info---
# <class 'pandas.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   0 non-null      float64
#  1   Close   0 non-null      float64
#  2   High    0 non-null      float64
#  3   Low     0 non-null      float64
#  4   Open    0 non-null      float64
#  5   Volume  0 non-null      float64
# dtypes: float64(6)
# memory usage: 132.0 bytes
# None
#
# --- Data Head ---
# Empty DataFrame
# Columns: [Price, Close, High, Low, Open, Volume]
# Index: []

# %%
df_check = pd.read_csv('../data_set/row/Nifty_50_India_2000_2026.csv')
print("--Pehli 5 rows ka origina data ---")
print(df_check.head())
print("\n--kisi ek price ka data type check--")
print(type(df_check['Price'].iloc[0]))
print("Pehli value:", df_check['Price'].iloc[0])
# Out:
# --Pehli 5 rows ka origina data ---
#         Price             Close             High               Low  \
# 0      Ticker             ^NSEI            ^NSEI             ^NSEI
# 1        Date               NaN              NaN               NaN
# 2  2007-09-17  4494.64990234375  4549.0498046875  4482.85009765625
# 3  2007-09-18   4546.2001953125  4551.7998046875   4481.5498046875
# 4  2007-09-19  4732.35009765625           4739.0           4550.25
#
#                Open Volume
# 0             ^NSEI  ^NSEI
# 1               NaN    NaN
# 2   4518.4501953125      0
# 3  4494.10009765625      0
# 4           4550.25      0
#
# --kisi ek price ka data type check--
# <class 'str'>
# Pehli value: Ticker
